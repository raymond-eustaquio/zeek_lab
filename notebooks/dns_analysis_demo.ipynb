# %%
# %cd ~/zeek_lab/scripts/
# !python3.10 ../scripts/demo_status_check.py
# Out:
# /home/raymo/zeek_lab/scripts
#
# === DEMO STATUS CHECK ===
#
#
# === DEMO STATUS CHECK ===
#
# Checking Splunk status...
# Demo mode: Splunk status check skipped.
#
# Checking Jupyter Lab status...
# Jupyter Lab is running:
# 1139 jupyter-lab
#
#
# Checking project directories and files...
#
# Lab root: OK (/home/raymo/zeek_lab)
# Scripts directory: OK (/home/raymo/zeek_lab/scripts)
# Notebooks directory: OK (/home/raymo/zeek_lab/notebooks)
# PCAP directory: OK (/home/raymo/zeek_lab/pcaps)
# Logs root: OK (/home/raymo/zeek_lab/logs)
# Generated data directory: OK (/home/raymo/zeek_lab/data/generated)
#
# Checking for PCAP files...
# PCAPs found.
#
# Checking for Zeek logs...
# Logs found in logs/.
#
# Checking generated data...
# Generated data found in data/generated/.
#
# Demo environment check complete.

# %%
# !python3.10 ../scripts/reset_lab.py
# !ls -al
# Out:
# === Resetting Zeek Lab Environment ===
# LAB_DIR:        /home/raymo/zeek_lab
# LOG_ROOT:       /home/raymo/zeek_lab/logs
# GENERATED_DIR:  /home/raymo/zeek_lab/data/generated
# IMAGES_DIR:     /home/raymo/zeek_lab/images
#
# Cleaning logs...
# Removed: /home/raymo/zeek_lab/logs
# Cleaning generated data...
# Removed: /home/raymo/zeek_lab/data/generated
# Cleaning PNGs in images/ ...
# Removed 0 PNG files from /home/raymo/zeek_lab/images
#
# Reset complete.
# Next step: run process_pcaps.sh to regenerate logs.
# total 36
# drwxr-xr-x  3 raymo raymo 4096 Jun  7 12:11 .
# drwxr-xr-x 12 raymo raymo 4096 Jun  7 12:11 ..
# drwxr-xr-x  2 raymo raymo 4096 Jun  3 07:16 .ipynb_checkpoints
# -rw-r--r--  1 raymo raymo 3100 Jun  7 12:11 demo_status_check.py
# -rw-r--r--  1 raymo raymo 3842 Jun  7 10:10 dns_analysis.py
# -rw-r--r--  1 raymo raymo 2110 Jun  7 10:04 dns_to_json.py
# -rwxr-xr-x  1 raymo raymo 1111 Jun  6 16:56 pretty.sh
# -rwxr-xr-x  1 raymo raymo  684 Jun  6 16:51 pretty_all.sh
# -rw-r--r--  1 raymo raymo 1651 Jun  6 17:10 reset_lab.py

# %%
# %cd ~/zeek_lab
# !bash process_pcaps.sh
# !ls -al
# list the directory
# !ls -al logs/*
# Out:
# /home/raymo/zeek_lab
# Using PCAP_DIR: /home/raymo/zeek_lab/pcaps
# Using LOG_ROOT: /home/raymo/zeek_lab/logs
#
# Processing /home/raymo/zeek_lab/pcaps/NetworkTraffic.pcap → /home/raymo/zeek_lab/logs/logs_NetworkTraffic
# 1741231902.551541 warning in /opt/zeek/share/zeek/base/misc/find-filtered-trace.zeek, line 69: The analyzed trace file was determined to contain only TCP control packets, which may indicate it's been pre-filtered.  By default, Zeek reports the missing segments for this type of trace, but the 'detect_filtered_trace' option may be toggled if that's not desired.
# Processing /home/raymo/zeek_lab/pcaps/college_dns_noise.pcap → /home/raymo/zeek_lab/logs/logs_college_dns_noise
# Processing /home/raymo/zeek_lab/pcaps/traffic.pcap → /home/raymo/zeek_lab/logs/logs_traffic
#
# All PCAPs processed.
# total 60
# drwxr-xr-x 12 raymo raymo 4096 Jun  7 12:11 .
# drwxr-x--- 18 raymo raymo 4096 Jun  7 12:11 ..
# drwxr-xr-x  8 raymo raymo 4096 Jun  7 12:11 .git
# -rw-r--r--  1 raymo raymo  472 Jun  7 08:25 .gitignore
# drwxr-xr-x  2 raymo raymo 4096 Jun  6 17:32 .ipynb_checkpoints
# -rw-r--r--  1 raymo raymo  531 Jun  6 16:06 Dockerfile
# drwxr-xr-x  3 raymo raymo 4096 Jun  7 12:11 data
# drwxr-xr-x  2 raymo raymo 4096 Jun  7 09:29 docs
# drwxr-xr-x  2 raymo raymo 4096 Jun  6 17:11 images
# drwxr-xr-x  3 raymo raymo 4096 May 29 11:24 integrations
# drwxr-xr-x  5 raymo raymo 4096 Jun  7 12:12 logs
# drwxr-xr-x  3 raymo raymo 4096 Jun  7 12:10 notebooks
# drwxr-xr-x  2 raymo raymo 4096 Jun  6 16:26 pcaps
# -rwxr-xr-x  1 raymo raymo  632 Jun  7 09:42 process_pcaps.sh
# drwxr-xr-x  3 raymo raymo 4096 Jun  7 12:11 scripts
# logs/logs_NetworkTraffic:
# total 24
# drwxr-xr-x 2 raymo raymo 4096 Jun  7 12:12 .
# drwxr-xr-x 5 raymo raymo 4096 Jun  7 12:12 ..
# -rw-r--r-- 1 raymo raymo  610 Jun  7 12:12 conn.log
# -rw-r--r-- 1 raymo raymo  278 Jun  7 12:12 packet_filter.log
# -rw-r--r-- 1 raymo raymo  570 Jun  7 12:12 reporter.log
# -rw-r--r-- 1 raymo raymo  486 Jun  7 12:12 weird.log
#
# logs/logs_college_dns_noise:
# total 20
# drwxr-xr-x 2 raymo raymo 4096 Jun  7 12:12 .
# drwxr-xr-x 5 raymo raymo 4096 Jun  7 12:12 ..
# -rw-r--r-- 1 raymo raymo 2025 Jun  7 12:12 conn.log
# -rw-r--r-- 1 raymo raymo 2297 Jun  7 12:12 dns.log
# -rw-r--r-- 1 raymo raymo  278 Jun  7 12:12 packet_filter.log
#
# logs/logs_traffic:
# total 24
# drwxr-xr-x 2 raymo raymo 4096 Jun  7 12:12 .
# drwxr-xr-x 5 raymo raymo 4096 Jun  7 12:12 ..
# -rw-r--r-- 1 raymo raymo 3858 Jun  7 12:12 conn.log
# -rw-r--r-- 1 raymo raymo 3376 Jun  7 12:12 dns.log
# -rw-r--r-- 1 raymo raymo 3516 Jun  7 12:12 ntp.log
# -rw-r--r-- 1 raymo raymo  278 Jun  7 12:12 packet_filter.log

# %%
# %cd ~/zeek_lab/notebooks

import pandas as pd
from IPython.display import HTML

# Load the Zeek DNS JSON (newline-delimited JSON)
df = pd.read_json("../data/generated/dns.json", lines=True)


# Display full-width scrollable table
HTML(f"""
<div style="width:100%; overflow-x:auto;">
    {df.to_html()}
</div>
""")
# Out:
# /home/raymo/zeek_lab/notebooks
# <div style="width:100%; overflow-x:auto;">
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ts</th>
#       <th>uid</th>
#       <th>id.orig_h</th>
#       <th>id.orig_p</th>
#       <th>id.resp_h</th>
#       <th>id.resp_p</th>
#       <th>proto</th>
#       <th>trans_id</th>
#       <th>rtt</th>
#       <th>query</th>
#       <th>qclass</th>
#       <th>qclass_name</th>
#       <th>qtype</th>
#       <th>qtype_name</th>
#       <th>rcode</th>
#       <th>rcode_name</th>
#       <th>AA</th>
#       <th>TC</th>
#       <th>RD</th>
#       <th>RA</th>
#       <th>Z</th>
#       <th>answers</th>
#       <th>TTLs</th>
#       <th>rejected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.755686e+09</td>
#       <td>CfsPRYlAnYPYZDep</td>
#       <td>192.168.56.101</td>
#       <td>53012</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>47945</td>
#       <td>0.035759</td>
#       <td>apples.ctf.local</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>16</td>
#       <td>TXT</td>
#       <td>0</td>
#       <td>NOERROR</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>T</td>
#       <td>0</td>
#       <td>TXT 28 TFNDVEZ7RE5TX0VYRklMX0ZVTn0=</td>
#       <td>120.000000</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.755686e+09</td>
#       <td>C5dzhd2QKFBdVqCsG8</td>
#       <td>192.168.56.101</td>
#       <td>53000</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>60399</td>
#       <td>-</td>
#       <td>www.google.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.755686e+09</td>
#       <td>CdrAerqzYTg2UKjud</td>
#       <td>192.168.56.101</td>
#       <td>53001</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>17667</td>
#       <td>-</td>
#       <td>example.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.755686e+09</td>
#       <td>Cf6FnZEAwePhwz72i</td>
#       <td>192.168.56.101</td>
#       <td>53002</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>61514</td>
#       <td>-</td>
#       <td>www.facebook.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.755686e+09</td>
#       <td>CqA8sd2WElHzW7odH6</td>
#       <td>192.168.56.101</td>
#       <td>53003</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>45594</td>
#       <td>-</td>
#       <td>api.github.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.755686e+09</td>
#       <td>CCBCVa2fwmAcgvhdfk</td>
#       <td>192.168.56.101</td>
#       <td>53004</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>37112</td>
#       <td>-</td>
#       <td>docs.python.org</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1.755686e+09</td>
#       <td>CKXtAE3qlYqndX8mud</td>
#       <td>192.168.56.101</td>
#       <td>53005</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>61162</td>
#       <td>-</td>
#       <td>news.ycombinator.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.755686e+09</td>
#       <td>CE0idl3328ujsx6tx2</td>
#       <td>192.168.56.101</td>
#       <td>53006</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>32251</td>
#       <td>-</td>
#       <td>login.microsoftonline.com</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.755686e+09</td>
#       <td>C19M774FtcuOibKEyf</td>
#       <td>192.168.56.101</td>
#       <td>53007</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>18801</td>
#       <td>-</td>
#       <td>cdn.jsdelivr.net</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1.755686e+09</td>
#       <td>Ciz7v7ztYEkzUvSyj</td>
#       <td>192.168.56.101</td>
#       <td>53008</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>36901</td>
#       <td>-</td>
#       <td>pypi.org</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1.755686e+09</td>
#       <td>C0bmxw2XL7j7pry0Ld</td>
#       <td>192.168.56.101</td>
#       <td>53009</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>1674</td>
#       <td>-</td>
#       <td>content.delivery.net</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>1</td>
#       <td>A</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1.755686e+09</td>
#       <td>C8d29c2zBogpjH5rch</td>
#       <td>192.168.56.101</td>
#       <td>53010</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>15451</td>
#       <td>-</td>
#       <td>red.herring.ctf.local</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>16</td>
#       <td>TXT</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1.755686e+09</td>
#       <td>CeegVt3QyzEak1zTEi</td>
#       <td>192.168.56.101</td>
#       <td>53011</td>
#       <td>8.8.8.8</td>
#       <td>53</td>
#       <td>udp</td>
#       <td>30091</td>
#       <td>-</td>
#       <td>totally-normal.example.net</td>
#       <td>1</td>
#       <td>C_INTERNET</td>
#       <td>16</td>
#       <td>TXT</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#       <td>F</td>
#       <td>T</td>
#       <td>F</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>F</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from IPython.display import HTML
pd.set_option('display.width', 2000)
pd.set_option('display.max_columns', None)

display(HTML(
    '''
    <div style="margin-bottom:20px;">
      <h1 style="margin:0 0 10px 0; font-family:Arial, sans-serif;">
        DNS Analysis Demo
      </h1>
      <p style="margin:0 0 10px 0; color:#555;">
        Scrollable view of the Zeek dns.log DataFrame.
      </p>
      <div style="width:100%; overflow-x:auto;">
        {table}
      </div>
    </div>
    '''.format(table=df.to_html())
))


from IPython.display import HTML, display

# BASIC SUMMARY
display(HTML("<h2 style='margin-top:25px;'>Basic Summary</h2>"))
df.info()

# TOP QUERIED DOMAINS
display(HTML("<h2 style='margin-top:25px;'>Top Queried Domains</h2>"))
print(df['query'].value_counts().to_string())

# QUERY TYPES
display(HTML("<h2 style='margin-top:25px;'>Query Types</h2>"))
print(df['qtype_name'].value_counts().to_string())

# RESPONSE CODES
display(HTML("<h2 style='margin-top:25px;'>Response Codes</h2>"))
print(df['rcode_name'].value_counts().to_string())

# TOP CLIENTS
display(HTML("<h2 style='margin-top:25px;'>Top Clients (id.orig_h)</h2>"))
print(df['id.orig_h'].value_counts().to_string())

# TOP DNS SERVERS
display(HTML("<h2 style='margin-top:25px;'>Top DNS Servers (id.resp_h)</h2>"))
print(df['id.resp_h'].value_counts().to_string())

# REJECTED QUERIES
display(HTML("<h2 style='margin-top:25px;'>Rejected Queries</h2>"))
print(df[df['rejected'] == True].to_string(index=False))

# %%
# %cd ~/zeek_lab/scripts
# !python3.10 dns_analysis.py ../logs/logs_college_dns_noise/dns.log
from IPython.display import Image, display
display(Image("../data/generated/dns_top_domains.png"))

# %%
print("# Zeek Version Discovery Demo using \"RG\"\n")

print("## 1. List all #define entries in zeek-version.h\n")
print("Command:")
print("  rg \"^#define\" /opt/zeek/include/zeek/zeek-version.h\n")

# !rg "^#define" /opt/zeek/include/zeek/zeek-version.h

print("\n## 2. Search for specific Zeek version macros\n")
print("Command:")
print("  rg -B 1 -A 1 \"^#define ZEEK_VERSION\" -i /opt/zeek/include/zeek/zeek-version.h\n")

# !rg -B 1 -A 1 "^#define ZEEK_VERSION" -i /opt/zeek/include/zeek/zeek-version.h

# %%
df['rcode_name'].value_counts()

# %%
import base64

data = "TFNDVEZ7RE5TX0VYRklMX0ZVTn0="
decoded = base64.b64decode(data).decode()
decoded

# %%
def decode_answer(data):
    decoded = base64.b64decode(data).decode()
    return decoded

if __name__ == "__main__":
    data = "TFNDVEZ7RE5TX0VYRklMX0ZVTn0="
    print(decode_answer(data))
